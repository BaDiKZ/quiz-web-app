# %% [markdown]
# <a href="https://colab.research.google.com/github/BaDiKZ/quiz-web-app/blob/main/wstep_do_srodowiska.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Podstawowe elementy jezyka python**
# W tym rozdziale przedstawimy podstawowe elementy
# składni języka Python. Poniżej dodajemy link do strony Pythona
# https://www.python.org/.

# %% [markdown]
# ## Omawiane elementy
#
# 1. Zmienne
# ---
# 2. Listy
# ---
# 3. Pętle
# ---
# 4. Słowniki i krotki
# ---
# 5. Instrukcje warunkowe
# ---
# 6. Funkcje
# ---
# 7. Obsługa plików
# ---
# 8. Obsługa wyjątków

# %% [markdown]
# ## Wstep
